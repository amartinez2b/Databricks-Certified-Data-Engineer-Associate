# %% [markdown]
# # 🎯 Ejercicio Final — Proyecto Integrador
#
# ## 🧠 Descripción general
#
# Simularemos una situación en la que trabajás como analista de datos para una empresa que desea analizar el comportamiento de sus clientes y sus compras recientes. Contarás con dos datasets:
# Un archivo CSV con los datos de clientes.
# Un archivo JSON con el historial de transacciones.
# Vas a aplicar distintas transformaciones, uniones, filtros, cálculos y guardado de resultados.
#
# ## 📦 Archivos entregados
#
# 🧍 clientes.csv
#
# Puedes crear archivos de prueba con los siguientes esquemas:
#
# - clienteID
# - nombre
# - pais
# - fecha_registro
#
# 🛒 transacciones.json
#
# - transID
# - clienteID
# - fecha_compra
# - producto
# - cantidad
# - precio_unitario
#
# ## 🧪 Actividades
#
# ### Lectura de archivo
# Lee el CSV de clientes y el JSON de transacciones en PySpark
# Muestra el esquema y las primeras filas de cada uno.
#
# ### Operaciones básicas
# Selecciona columnas clave (nombre, pais, fecha_compra, producto, etc.).
# Filtra transacciones mayores a 500 pesos en total.
# Funciones SQL
# Usa selectExpr para calcular el total de cada transacción (cantidad * precio_unitario).
# Crea una columna con el nombre del país en mayúsculas.
#
# ### Agrupaciones
# Agrupa por cliente y calculá el total gastado.
#
# ### Join entre datasets
# Une los clientes con sus transacciones usando clienteID.
#
# ### Manejo de fechas
# Convierte las columnas de fecha.
# Calcula la antigüedad del cliente (en días desde la fecha_registro).
# Aplicación de UDFs
# Creá una UDF que clasifique el cliente según su antigüedad:
# < 365 días → “Nuevo”
# >= 365 días → “Frecuente”
# Aplicá otra UDF que categorice el total de gasto:
# <1000 → Bajo
# 1000–3000 → Medio
# >3000 → Alto
#
# ### Escritura final
# Guarda el resultado completo como archivo Parquet y también como CSV delimitado por |.
# ✅ Resultado esperado
#
# Un DataFrame con columnas como:
#
# - clienteID
# - nombre
# - pais
# - total_gasto
# - antiguedad_dias
# - categoria_cliente
# - nivel_gasto
#
# ## 📤 Entregable
# Notebook o script .py con:
# Lectura, transformación, joins, UDFs y guardado.
# Comentarios explicativos en cada paso.
